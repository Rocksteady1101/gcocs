# %%
import pandas

# %%
league = pandas.read_csv('1718_E0.csv', index_col=None)

# %%
league
# Out:
#     Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  11/08/17         Arsenal       Leicester     4     3   H     2     2
# 1    E0  12/08/17        Brighton        Man City     0     2   A     0     0
# 2    E0  12/08/17         Chelsea         Burnley     2     3   A     0     3
# 3    E0  12/08/17  Crystal Palace    Huddersfield     0     3   A     0     2
# 4    E0  12/08/17         Everton           Stoke     1     0   H     1     0
# 5    E0  12/08/17     Southampton         Swansea     0     0   D     0     0
# 6    E0  12/08/17         Watford       Liverpool     3     3   D     2     1
# 7    E0  12/08/17       West Brom     Bournemouth     1     0   H     1     0
# 8    E0  13/08/17      Man United        West Ham     4     0   H     1     0
# 9    E0  13/08/17       Newcastle       Tottenham     0     2   A     0     0
# 10   E0  19/08/17     Bournemouth         Watford     0     2   A     0     0
# ...

# %%
league.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 65 columns):
# Div         380 non-null object
# Date        380 non-null object
# HomeTeam    380 non-null object
# AwayTeam    380 non-null object
# FTHG        380 non-null int64
# FTAG        380 non-null int64
# FTR         380 non-null object
# HTHG        380 non-null int64
# HTAG        380 non-null int64
# HTR         380 non-null object
# Referee     380 non-null object
# HS          380 non-null int64
# AS          380 non-null int64
# HST         380 non-null int64
# AST         380 non-null int64
# HF          380 non-null int64
# AF          380 non-null int64
# HC          380 non-null int64
# AC          380 non-null int64
# HY          380 non-null int64
# AY          380 non-null int64
# HR          380 non-null int64
# AR          380 non-null int64
# B365H       380 non-null float64
# B365D       380 non-null float64
# B365A       380 non-null float64
# ...

# %%
home=league['HomeTeam']
home
# Out:
# 0             Arsenal
# 1            Brighton
# 2             Chelsea
# 3      Crystal Palace
# 4             Everton
# 5         Southampton
# 6             Watford
# 7           West Brom
# 8          Man United
# 9           Newcastle
# 10        Bournemouth
# 11            Burnley
# 12          Leicester
# 13          Liverpool
# 14        Southampton
# 15              Stoke
# 16            Swansea
# 17       Huddersfield
# 18          Tottenham
# 19           Man City
# 20        Bournemouth
# 21     Crystal Palace
# 22       Huddersfield
# 23         Man United
# 24          Newcastle
# 25            Watford
# 26            Chelsea
# 27          Liverpool
# 28          Tottenham
# 29          West Brom
#             ...
# 350           Swansea
# 351        Man United
# 352          West Ham
# 353         Tottenham
# 354          Brighton
# 355       Bournemouth
# 356           Everton
# 357         Leicester
# 358             Stoke
# 359           Watford
# ...

# %%
league.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'PSH', 'PSD', 'PSA',
#        'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH',
#        'BbMxD', 'BbAvD', 'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5',
#        'BbMx<2.5', 'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH',
#        'BbMxAHA', 'BbAvAHA', 'PSCH', 'PSCD', 'PSCA'],
#       dtype='object')

# %%
league.index
# Out:
# RangeIndex(start=0, stop=380, step=1)

# %%
league.describe
# Out:
# <bound method NDFrame.describe of     Div      Date        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0    E0  11/08/17         Arsenal       Leicester     4     3   H     2     2
# 1    E0  12/08/17        Brighton        Man City     0     2   A     0     0
# 2    E0  12/08/17         Chelsea         Burnley     2     3   A     0     3
# 3    E0  12/08/17  Crystal Palace    Huddersfield     0     3   A     0     2
# 4    E0  12/08/17         Everton           Stoke     1     0   H     1     0
# 5    E0  12/08/17     Southampton         Swansea     0     0   D     0     0
# 6    E0  12/08/17         Watford       Liverpool     3     3   D     2     1
# 7    E0  12/08/17       West Brom     Bournemouth     1     0   H     1     0
# 8    E0  13/08/17      Man United        West Ham     4     0   H     1     0
# 9    E0  13/08/17       Newcastle       Tottenham     0     2   A     0     0
# 10   E0  19/08/17     Bournemouth         Watford     0     2   A     0     0
# ...

# %%
indexed = league.set_index(['Date', 'FTHG'])
indexed
# Out:
#               Div        HomeTeam        AwayTeam  FTAG FTR  HTHG  HTAG HTR  \
# Date     FTHG
# 11/08/17 4     E0         Arsenal       Leicester     3   H     2     2   D
# 12/08/17 0     E0        Brighton        Man City     2   A     0     0   D
#          2     E0         Chelsea         Burnley     3   A     0     3   A
#          0     E0  Crystal Palace    Huddersfield     3   A     0     2   A
#          1     E0         Everton           Stoke     0   H     1     0   H
#          0     E0     Southampton         Swansea     0   D     0     0   D
#          3     E0         Watford       Liverpool     3   D     2     1   H
#          1     E0       West Brom     Bournemouth     0   H     1     0   H
# 13/08/17 4     E0      Man United        West Ham     0   H     1     0   H
#          0     E0       Newcastle       Tottenham     2   A     0     0   D
# 19/08/17 0     E0     Bournemouth         Watford     2   A     0     0   D
# ...

# %%
import matplotlib
# %matplotlib inline

league['HomeTeam']
#ind.index = league['Date']
#ind
#ind=league.set_index(['FTHG'])
#ind
#ind.loc['Date']
#indexed.Loc['Date'].plot()
#league.plot(['Date'])
#league.loc[2].dropna().plot()
# Out:
# 0             Arsenal
# 1            Brighton
# 2             Chelsea
# 3      Crystal Palace
# 4             Everton
# 5         Southampton
# 6             Watford
# 7           West Brom
# 8          Man United
# 9           Newcastle
# 10        Bournemouth
# 11            Burnley
# 12          Leicester
# 13          Liverpool
# 14        Southampton
# 15              Stoke
# 16            Swansea
# 17       Huddersfield
# 18          Tottenham
# 19           Man City
# 20        Bournemouth
# 21     Crystal Palace
# 22       Huddersfield
# 23         Man United
# 24          Newcastle
# 25            Watford
# 26            Chelsea
# 27          Liverpool
# 28          Tottenham
# 29          West Brom
#             ...
# 350           Swansea
# 351        Man United
# 352          West Ham
# 353         Tottenham
# 354          Brighton
# 355       Bournemouth
# 356           Everton
# 357         Leicester
# 358             Stoke
# 359           Watford
# ...

# %%
league.loc['01/01/18',3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [01/01/18] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-aac7b996a8d4> in <module>()
# ----> 1 league.loc['01/01/18',3]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
league.index
# Out:
# RangeIndex(start=0, stop=380, step=1)

# %%
league[['Date','FTHG','FTAG']].plot()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
fig, ax = plt.subplots(figsize=(15,7))
league[['Date','FTHG','FTAG']].plot(ax=ax)
#set ticks every week
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#set major ticks format
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# %%
#set ticks every week
ax.xaxis.set_major_locator(mdates.WeekdayLocator())
#set major ticks format
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
league[['Date','FTHG','FTAG']].plot.bar();
